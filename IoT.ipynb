# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import missingno as msno

# %%
df = pd.read_csv('C:\\Users\\piyus\\OneDrive\\Desktop\\New folder (2)\\Agriculture_IoT\\IoT_Data.csv')

# %%
df.head(10)
# Out:
#                   date  tempreature  humidity  water_level    N    P    K  \
# 0  2024-02-08 06:10:00           41        63          100  255  255  255
# 1  2024-02-08 06:15:00           41        59          100  255  255  255
# 2  2024-02-08 06:20:00           41        62          100  255  255  255
# 3  2024-02-08 06:05:00           40        60          100  255  255  255
# 4  2024-02-08 06:00:00           39        61          100  255  255  255
# 5  2024-01-18 06:02:00           38        64          100  255  255  255
# 6  2024-01-18 06:07:00           38        65          100  255  255  255
# 7  2024-01-18 06:12:00           38        64          100  255  255  255
# 8  2024-01-18 05:02:00           37        62          100  255  255  255
# 9  2024-01-18 05:07:00           37        63          100  255  255  255
#
#    Fan_actuator_OFF  Fan_actuator_ON  Watering_plant_pump_OFF  \
# 0               0.0              1.0                      1.0
# ...

# %%
# Get the data type info and not null values

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37922 entries, 0 to 37921
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   date                     37920 non-null  object
#  1   tempreature              37922 non-null  int64
#  2   humidity                 37922 non-null  int64
#  3   water_level              37922 non-null  int64
#  4   N                        37922 non-null  int64
#  5   P                        37922 non-null  int64
#  6   K                        37922 non-null  int64
#  7   Fan_actuator_OFF         37922 non-null  float64
#  8   Fan_actuator_ON          37922 non-null  float64
#  9   Watering_plant_pump_OFF  37922 non-null  float64
#  10  Watering_plant_pump_ON   37922 non-null  float64
#  11  Water_pump_actuator_OFF  37922 non-null  float64
#  12  Water_pump_actuator_ON   37922 non-null  float64
# dtypes: float64(6), int64(6), object(1)
# ...

# %%
# Lets Count the value

df.count()
# Out:
# date                       37920
# tempreature                37922
# humidity                   37922
# water_level                37922
# N                          37922
# P                          37922
# K                          37922
# Fan_actuator_OFF           37922
# Fan_actuator_ON            37922
# Watering_plant_pump_OFF    37922
# Watering_plant_pump_ON     37922
# Water_pump_actuator_OFF    37922
# Water_pump_actuator_ON     37922
# dtype: int64

# %%
# Lets highlight the column to know about its lables or feature

df.columns
# Out:
# Index(['date', 'tempreature', 'humidity', 'water_level', 'N', 'P', 'K',
#        'Fan_actuator_OFF', 'Fan_actuator_ON', 'Watering_plant_pump_OFF',
#        'Watering_plant_pump_ON', 'Water_pump_actuator_OFF',
#        'Water_pump_actuator_ON'],
#       dtype='object')

# %%
msno.matrix(df)
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.heatmap(
    df.isnull(),
    cmap= 'inferno',
    cbar = False,
    yticklables = False,

)

plt.title('Binary Heatmap of missing data')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 2
#       1 plt.figure(figsize=(6,4))
# ----> 2 sns.heatmap(
#       3     df.isnull(),
#       4     cmap= 'inferno',
#       5     cbar = False,
#       6     yticklables = False,
#       7
#       8 )
#      10 plt.title('Binary Heatmap of missing data')
#      11 plt.show()
#
# File c:\Users\piyus\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\matrix.py:459, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     457 if square:
#     458     ax.set_aspect("equal")
# --> 459 plotter.plot(ax, cbar_ax, kwargs)
#     460 return ax
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Assuming df is already defined and is a DataFrame
plt.figure(figsize=(6, 4))
sns.heatmap(
    df.isnull(),
    cmap='inferno',
    cbar=False,
    yticklabels=False
)

plt.title('Binary Heatmap of Missing Data')
plt.show()

# %%
df.describe()
# Out:
#         tempreature      humidity   water_level             N             P  \
# count  37922.000000  37922.000000  37922.000000  37922.000000  37922.000000
# mean      18.760113     50.329308     79.401587    231.963610    234.123332
# std        7.143422     22.995645     36.824610     34.718121     31.452138
# min        3.000000      0.000000      0.000000      0.000000      0.000000
# 25%       13.000000     49.000000     79.000000    185.000000    190.000000
# 50%       17.000000     59.000000    100.000000    255.000000    255.000000
# 75%       25.000000     62.000000    100.000000    255.000000    255.000000
# max       41.000000    100.000000    100.000000    255.000000    255.000000
#
#                   K  Fan_actuator_OFF  Fan_actuator_ON  \
# count  37922.000000      37922.000000     37922.000000
# mean     225.171879          0.689863         0.310137
# std       44.877635          0.462555         0.462555
# min        0.000000          0.000000         0.000000
# ...

# %%
df.shape
# Out:
# (37922, 13)

# %%
df.isnull().sum()
# Out:
# date                       2
# tempreature                0
# humidity                   0
# water_level                0
# N                          0
# P                          0
# K                          0
# Fan_actuator_OFF           0
# Fan_actuator_ON            0
# Watering_plant_pump_OFF    0
# Watering_plant_pump_ON     0
# Water_pump_actuator_OFF    0
# Water_pump_actuator_ON     0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# date                       0
# tempreature                0
# humidity                   0
# water_level                0
# N                          0
# P                          0
# K                          0
# Fan_actuator_OFF           0
# Fan_actuator_ON            0
# Watering_plant_pump_OFF    0
# Watering_plant_pump_ON     0
# Water_pump_actuator_OFF    0
# Water_pump_actuator_ON     0
# dtype: int64

# %%
list = df.hist(bins=12, figsize=(20, 20))
plt.savefig("Histo.png")
